# %% [markdown]
# ![test.png](attachment:1bd4f33a-7416-4e57-942e-f8089a4c2d05.png)

# %% [markdown]
# # Car Price Predection

# %% [markdown]
# ## EDA

# %%
# Load librires
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import math

# %%
data=pd.read_csv('car data.csv')
data.head(10)
# Out:
#         Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0           ritz  2014           3.35           5.59       27000    Petrol
# 1            sx4  2013           4.75           9.54       43000    Diesel
# 2           ciaz  2017           7.25           9.85        6900    Petrol
# 3        wagon r  2011           2.85           4.15        5200    Petrol
# 4          swift  2014           4.60           6.87       42450    Diesel
# 5  vitara brezza  2018           9.25           9.83        2071    Diesel
# 6           ciaz  2015           6.75           8.12       18796    Petrol
# 7        s cross  2015           6.50           8.61       33429    Diesel
# 8           ciaz  2016           8.75           8.89       20273    Diesel
# 9           ciaz  2015           7.45           8.92       42367    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0
# 5       Dealer       Manual      0
# 6       Dealer       Manual      0
# 7       Dealer       Manual      0
# 8       Dealer       Manual      0
# 9       Dealer       Manual      0

# %%
#shape of the data
data.shape
# Out:
# (301, 9)

# %%
#check the information of the datasett
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
#Describe function
data.describe().style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_4187a_row0_col0 {
#   background-color: #0025ec;
#   color: #f1f1f1;
# }
# #T_4187a_row0_col1, #T_4187a_row0_col2, #T_4187a_row0_col4, #T_4187a_row1_col0, #T_4187a_row4_col0, #T_4187a_row5_col0, #T_4187a_row6_col0, #T_4187a_row7_col0, #T_4187a_row7_col3 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_4187a_row0_col3, #T_4187a_row1_col4, #T_4187a_row2_col0, #T_4187a_row2_col4, #T_4187a_row3_col1, #T_4187a_row3_col2, #T_4187a_row3_col3, #T_4187a_row3_col4, #T_4187a_row4_col1, #T_4187a_row4_col2, #T_4187a_row4_col4, #T_4187a_row5_col4, #T_4187a_row6_col4 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_4187a_row1_col1 {
#   background-color: #0003fe;
#   color: #f1f1f1;
# }
# #T_4187a_row1_col2 {
#   background-color: #0006fc;
#   color: #f1f1f1;
# }
# #T_4187a_row1_col3 {
#   background-color: #0012f6;
#   color: #f1f1f1;
# }
# #T_4187a_row2_col1 {
#   background-color: #0004fd;
#   color: #f1f1f1;
# }
# #T_4187a_row2_col2, #T_4187a_row4_col3 {
#   background-color: #0007fc;
#   color: #f1f1f1;
# }
# #T_4187a_row2_col3 {
#   background-color: #0013f6;
#   color: #f1f1f1;
# }
# #T_4187a_row3_col0 {
#   background-color: #00fe80;
#   color: #000000;
# }
# #T_4187a_row5_col1, #T_4187a_row7_col4 {
#   background-color: #0002fe;
#   color: #f1f1f1;
# }
# #T_4187a_row5_col2, #T_4187a_row6_col1 {
#   background-color: #0005fc;
#   color: #f1f1f1;
# }
# #T_4187a_row5_col3 {
#   background-color: #0010f7;
#   color: #f1f1f1;
# }
# #T_4187a_row6_col2 {
#   background-color: #0008fb;
#   color: #f1f1f1;
# }
# #T_4187a_row6_col3 {
#   background-color: #0018f3;
#   color: #f1f1f1;
# }
# #T_4187a_row7_col1 {
#   background-color: #001df0;
#   color: #f1f1f1;
# }
# #T_4187a_row7_col2 {
#   background-color: #004ed8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4187a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4187a_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_4187a_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_4187a_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_4187a_level0_col3" class="col_heading level0 col3" >Driven_kms</th>
#       <th id="T_4187a_level0_col4" class="col_heading level0 col4" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4187a_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_4187a_row0_col0" class="data row0 col0" >301.000000</td>
#       <td id="T_4187a_row0_col1" class="data row0 col1" >301.000000</td>
#       <td id="T_4187a_row0_col2" class="data row0 col2" >301.000000</td>
#       <td id="T_4187a_row0_col3" class="data row0 col3" >301.000000</td>
#       <td id="T_4187a_row0_col4" class="data row0 col4" >301.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4187a_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_4187a_row1_col0" class="data row1 col0" >2013.627907</td>
#       <td id="T_4187a_row1_col1" class="data row1 col1" >4.661296</td>
#       <td id="T_4187a_row1_col2" class="data row1 col2" >7.628472</td>
#       <td id="T_4187a_row1_col3" class="data row1 col3" >36947.205980</td>
#       <td id="T_4187a_row1_col4" class="data row1 col4" >0.043189</td>
#     </tr>
#     <tr>
#       <th id="T_4187a_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_4187a_row2_col0" class="data row2 col0" >2.891554</td>
#       <td id="T_4187a_row2_col1" class="data row2 col1" >5.082812</td>
#       <td id="T_4187a_row2_col2" class="data row2 col2" >8.642584</td>
#       <td id="T_4187a_row2_col3" class="data row2 col3" >38886.883882</td>
#       <td id="T_4187a_row2_col4" class="data row2 col4" >0.247915</td>
#     </tr>
#     <tr>
#       <th id="T_4187a_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_4187a_row3_col0" class="data row3 col0" >2003.000000</td>
#       <td id="T_4187a_row3_col1" class="data row3 col1" >0.100000</td>
#       <td id="T_4187a_row3_col2" class="data row3 col2" >0.320000</td>
#       <td id="T_4187a_row3_col3" class="data row3 col3" >500.000000</td>
#       <td id="T_4187a_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4187a_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_4187a_row4_col0" class="data row4 col0" >2012.000000</td>
#       <td id="T_4187a_row4_col1" class="data row4 col1" >0.900000</td>
#       <td id="T_4187a_row4_col2" class="data row4 col2" >1.200000</td>
#       <td id="T_4187a_row4_col3" class="data row4 col3" >15000.000000</td>
#       <td id="T_4187a_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4187a_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_4187a_row5_col0" class="data row5 col0" >2014.000000</td>
#       <td id="T_4187a_row5_col1" class="data row5 col1" >3.600000</td>
#       <td id="T_4187a_row5_col2" class="data row5 col2" >6.400000</td>
#       <td id="T_4187a_row5_col3" class="data row5 col3" >32000.000000</td>
#       <td id="T_4187a_row5_col4" class="data row5 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4187a_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_4187a_row6_col0" class="data row6 col0" >2016.000000</td>
#       <td id="T_4187a_row6_col1" class="data row6 col1" >6.000000</td>
#       <td id="T_4187a_row6_col2" class="data row6 col2" >9.900000</td>
#       <td id="T_4187a_row6_col3" class="data row6 col3" >48767.000000</td>
#       <td id="T_4187a_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4187a_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_4187a_row7_col0" class="data row7 col0" >2018.000000</td>
#       <td id="T_4187a_row7_col1" class="data row7 col1" >35.000000</td>
#       <td id="T_4187a_row7_col2" class="data row7 col2" >92.600000</td>
#       <td id="T_4187a_row7_col3" class="data row7 col3" >500000.000000</td>
#       <td id="T_4187a_row7_col4" class="data row7 col4" >3.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Corelation matrix**

# %%
corr=data.corr().style.background_gradient(cmap='winter')
corr
# Out:
# C:\Users\Ameer_Hassan0000\AppData\Local\Temp\ipykernel_23276\2031040878.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr().style.background_gradient(cmap='winter')
# <style type="text/css">
# #T_ee04b_row0_col0, #T_ee04b_row1_col1, #T_ee04b_row2_col2, #T_ee04b_row3_col3, #T_ee04b_row4_col4 {
#   background-color: #00ff80;
#   color: #000000;
# }
# #T_ee04b_row0_col1 {
#   background-color: #004cd9;
#   color: #f1f1f1;
# }
# #T_ee04b_row0_col2, #T_ee04b_row0_col3, #T_ee04b_row0_col4, #T_ee04b_row3_col0, #T_ee04b_row4_col1 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_ee04b_row1_col0 {
#   background-color: #007fc0;
#   color: #f1f1f1;
# }
# #T_ee04b_row1_col2 {
#   background-color: #00e28e;
#   color: #000000;
# }
# #T_ee04b_row1_col3 {
#   background-color: #005cd1;
#   color: #f1f1f1;
# }
# #T_ee04b_row1_col4 {
#   background-color: #0014f5;
#   color: #f1f1f1;
# }
# #T_ee04b_row2_col0 {
#   background-color: #0050d7;
#   color: #f1f1f1;
# }
# #T_ee04b_row2_col1 {
#   background-color: #00e38e;
#   color: #000000;
# }
# #T_ee04b_row2_col3 {
#   background-color: #007ac2;
#   color: #f1f1f1;
# }
# #T_ee04b_row2_col4 {
#   background-color: #0029eb;
#   color: #f1f1f1;
# }
# #T_ee04b_row3_col1 {
#   background-color: #001bf2;
#   color: #f1f1f1;
# }
# #T_ee04b_row3_col2 {
#   background-color: #003de0;
#   color: #f1f1f1;
# }
# #T_ee04b_row3_col4 {
#   background-color: #003ae2;
#   color: #f1f1f1;
# }
# #T_ee04b_row4_col0 {
#   background-color: #0039e2;
#   color: #f1f1f1;
# }
# #T_ee04b_row4_col2 {
#   background-color: #000df8;
#   color: #f1f1f1;
# }
# #T_ee04b_row4_col3 {
#   background-color: #0067cc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ee04b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ee04b_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_ee04b_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_ee04b_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_ee04b_level0_col3" class="col_heading level0 col3" >Driven_kms</th>
#       <th id="T_ee04b_level0_col4" class="col_heading level0 col4" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ee04b_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_ee04b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_ee04b_row0_col1" class="data row0 col1" >0.236141</td>
#       <td id="T_ee04b_row0_col2" class="data row0 col2" >-0.047192</td>
#       <td id="T_ee04b_row0_col3" class="data row0 col3" >-0.524342</td>
#       <td id="T_ee04b_row0_col4" class="data row0 col4" >-0.182104</td>
#     </tr>
#     <tr>
#       <th id="T_ee04b_level0_row1" class="row_heading level0 row1" >Selling_Price</th>
#       <td id="T_ee04b_row1_col0" class="data row1 col0" >0.236141</td>
#       <td id="T_ee04b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_ee04b_row1_col2" class="data row1 col2" >0.878914</td>
#       <td id="T_ee04b_row1_col3" class="data row1 col3" >0.029187</td>
#       <td id="T_ee04b_row1_col4" class="data row1 col4" >-0.088344</td>
#     </tr>
#     <tr>
#       <th id="T_ee04b_level0_row2" class="row_heading level0 row2" >Present_Price</th>
#       <td id="T_ee04b_row2_col0" class="data row2 col0" >-0.047192</td>
#       <td id="T_ee04b_row2_col1" class="data row2 col1" >0.878914</td>
#       <td id="T_ee04b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_ee04b_row2_col3" class="data row2 col3" >0.203618</td>
#       <td id="T_ee04b_row2_col4" class="data row2 col4" >0.008058</td>
#     </tr>
#     <tr>
#       <th id="T_ee04b_level0_row3" class="row_heading level0 row3" >Driven_kms</th>
#       <td id="T_ee04b_row3_col0" class="data row3 col0" >-0.524342</td>
#       <td id="T_ee04b_row3_col1" class="data row3 col1" >0.029187</td>
#       <td id="T_ee04b_row3_col2" class="data row3 col2" >0.203618</td>
#       <td id="T_ee04b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_ee04b_row3_col4" class="data row3 col4" >0.089216</td>
#     </tr>
#     <tr>
#       <th id="T_ee04b_level0_row4" class="row_heading level0 row4" >Owner</th>
#       <td id="T_ee04b_row4_col0" class="data row4 col0" >-0.182104</td>
#       <td id="T_ee04b_row4_col1" class="data row4 col1" >-0.088344</td>
#       <td id="T_ee04b_row4_col2" class="data row4 col2" >0.008058</td>
#       <td id="T_ee04b_row4_col3" class="data row4 col3" >0.089216</td>
#       <td id="T_ee04b_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Let's visualize the correlation matrix iin the seaborn
sns.set(rc={'figure.figsize':(10,6)})
sns.heatmap(data.corr(),annot=True,cmap='winter')
# Out:
# C:\Users\Ameer_Hassan0000\AppData\Local\Temp\ipykernel_23276\2893601010.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True,cmap='winter')
# <Axes: >

# %%
#data columns
data.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# **Explore Data analysis (EDA)**

# %%
#Let's visualize the car names in the dataset
car_names=data['Car_Name'].value_counts()
#To visualize the top 20 car's sold
label=['city','corolla altis','verna','fortuner','brio','ciaz','innova','i20','grand i10','jazz','amaze','Royal Enfield Classic 350','ertiga','eon','sx4','alto k10','i10','swift','Bajaj Pulsar 150','Royal Enfield Thunder 350']
plt.figure(figsize=(16,9))
plt.pie(car_names[:20],labels=label, autopct='%1.2f%%')
plt.title(" top 20 cars sold",fontsize=20,fontweight='bold')
plt.show()

# %%
plt.rcParams['figure.figsize']=(10,6)
sns.countplot(data=data,x='Year')
plt.xlabel('Year')
plt.title('Cars Sold in Each Year')
# Out:
# Text(0.5, 1.0, 'Cars Sold in Each Year')

# %%
#Let's visualize the car names in the dataset
fuel_type=data['Fuel_Type'].value_counts()
#To visualize the top 20 car's sold
label=['Petrol','Diesel','CNG']
plt.figure(figsize=(10,6))
plt.pie(fuel_type,labels=label, autopct='%1.2f%%',colors=['#22668D','#FFCC70','#8ECDDD'])
plt.title("Fuel Type ",fontsize=20,fontweight='bold')
plt.show()

# %%
plt.rcParams['figure.figsize']=(8,6)
#to visualize the Selling_Price in the dataset
sns.histplot(data['Selling_Price'],kde=True)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Count'>

# %%
# Draw a vertical boxplot grouped 
# by a categorical variable:
sns.set_style("whitegrid")
sns.boxplot(y = 'Present_Price', x = 'Fuel_Type', data = data)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Present_Price'>

# %%
# Draw a vertical boxplot grouped 
# by a categorical variable:
sns.set_style("whitegrid")
sns.boxplot(y ='Present_Price', x = 'Selling_type', data = data)
# Out:
# <Axes: xlabel='Selling_type', ylabel='Present_Price'>

# %%
# Draw a vertical boxplot grouped 
# by a categorical variable:
sns.set_style("whitegrid")
sns.boxplot(y ='Selling_Price', x = 'Transmission', data = data)
# Out:
# <Axes: xlabel='Transmission', ylabel='Selling_Price'>

# %% [markdown]
# # **Model buliding**

# %% [markdown]
# #  **Labelencoder**

# %%
#Let's import the labelencoder covert the categorical data to numerical
from sklearn.preprocessing import LabelEncoder,StandardScaler
label=LabelEncoder()
data['Car_Name']=label.fit_transform(data['Car_Name'])
data['Fuel_Type']=label.fit_transform(data['Fuel_Type'])
data['Selling_type']=label.fit_transform(data['Selling_type'])
data['Transmission']=label.fit_transform(data['Transmission'])

# %%
#Let's divided the data into input into target
X=data.drop(['Selling_Price'],axis=1)
y=data['Selling_Price']

# %%
#normalize the data
scaler=StandardScaler()
#Let's normalize the train dataset
X=scaler.fit_transform(X)

# %%
#divided the data into train and test
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# # LinearRegression

# %%
#Install the Linear regression model
linear=LinearRegression()
#let's fi the train data
linear.fit(X_train,y_train)
#Prediction of the test data
linear_pred=linear.predict(X_test)

# %%
#Check the test score and train score to the LinearRegression algorithm
print(f'The Test_accuracy: {linear.score(X_test,y_test)*100:.2f}')
#Train score for the data
print(f'The Train_accuracy: {linear.score(X_train,y_train)*100:.2f}')
# Out:
# The Test_accuracy: 87.50
# The Train_accuracy: 87.75
